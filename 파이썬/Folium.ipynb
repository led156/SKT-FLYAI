# %% [markdown]
# # Folium
# - 지도 시각화 도구

# %%
import folium

seoul_map = folium.Map(location=[37.4921263, 126.9261711], zoom_start=12, tiles='Stamen Toner')
# seoul_map.save('./seoul.html')

# %% [markdown]
# ## 예제1 : 서울 지역 대학교 지도에 찍어보기

# %%
import pandas as pd

df = pd.read_excel('./서울지역 대학교 위치.xlsx', engine='openpyxl', index_col=0)
df.head()
# Out:
#                      위도          경도
# KAIST 서울캠퍼스   37.592573  127.046737
# KC대학교         37.548345  126.854797
# 가톨릭대학교(성신교정)  37.585922  127.004328
# 가톨릭대학교(성의교정)  37.499623  127.006065
# 감리교신학대학교      37.567645  126.961610

# %%
seoul_map = folium.Map(location=[37.4921263, 126.9261711], zoom_start=12, tiles='Stamen Terrain')

for name, lat, lng in zip(df.index, df.위도, df.경도):
  folium.Marker([lat, lng], popup=name).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e073045958b63e25b99eb988a35d2b4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e073045958b63e25b99eb988a35d2b4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e073045958b63e25b99eb988a35d2b4e = L.map(
#                 &quot;map_e073045958b63e25b99eb988a35d2b4e&quot;,
#                 {
#                     center: [37.4921263, 126.9261711],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_720daf38d2383d509716725c88e6273a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e073045958b63e25b99eb988a35d2b4e);
#
#
#             var marker_30b23931957a3e03771e037717ad7f65 = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_e073045958b63e25b99eb988a35d2b4e);
#
#
#         var popup_51e8281ccc5fcb37c9744bef378bf74c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a25b907d51901333f9ec0d6c29decda4 = $(`&lt;div id=&quot;html_a25b907d51901333f9ec0d6c29decda4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#             popup_51e8281ccc5fcb37c9744bef378bf74c.setContent(html_a25b907d51901333f9ec0d6c29decda4);
#
#
#         marker_30b23931957a3e03771e037717ad7f65.bindPopup(popup_51e8281ccc5fcb37c9744bef378bf74c)
#         ;
#
#
#
#
#             var marker_d60725688b82a3d6ccf5371e007df989 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_e073045958b63e25b99eb988a35d2b4e);
#
#
#         var popup_7f7c1ef4e99d0578b791127b3ffd9713 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_909e0388a24cdaa8cd4522429a86b9a7 = $(`&lt;div id=&quot;html_909e0388a24cdaa8cd4522429a86b9a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#             popup_7f7c1ef4e99d0578b791127b3ffd9713.setContent(html_909e0388a24cdaa8cd4522429a86b9a7);
#
#
#         marker_d60725688b82a3d6ccf5371e007df989.bindPopup(popup_7f7c1ef4e99d0578b791127b3ffd9713)
#         ;
#
#
#
#
#             var marker_5d6db5923333a502460caeaf04dcaddf = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_e073045958b63e25b99eb988a35d2b4e);
#
#
#         var popup_273407fc8aa3400bf4450a1ffa2ef160 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c562921d2eff2bb194178b2eb64160a0 = $(`&lt;div id=&quot;html_c562921d2eff2bb194178b2eb64160a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#             popup_273407fc8aa3400bf4450a1ffa2ef160.setContent(html_c562921d2eff2bb194178b2eb64160a0);
#
#
#         marker_5d6db5923333a502460caeaf04dcaddf.bindPopup(popup_273407fc8aa3400bf4450a1ffa2ef160)
#         ;
#
#
#
#
#             var marker_5317d3409b06aec5e2e9294f9df72ca4 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_e073045958b63e25b99eb988a35d2b4e);
#
#
#         var popup_041d8e779c6c9b9644c91d318d1e1ec9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c81f8643c3f6c9bde84fb74e3cf2afda = $(`&lt;div id=&quot;html_c81f8643c3f6c9bde84fb74e3cf2afda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#             popup_041d8e779c6c9b9644c91d318d1e1ec9.setContent(html_c81f8643c3f6c9bde84fb74e3cf2afda);
#
#
#         marker_5317d3409b06aec5e2e9294f9df72ca4.bindPopup(popup_041d8e779c6c9b9644c91d318d1e1ec9)
#         ;
#
#
#
#
#             var marker_e8f8247b2a3f4a3c1464e45837924130 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_e073045958b63e25b99eb988a35d2b4e);
#
#
#         var popup_1917037b652c37127c115e885ef462b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ad68b0f5f72b20551cf1ce893ffd4781 = $(`&lt;div id=&quot;html_ad68b0f5f72b20551cf1ce893ffd4781&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#             popup_1917037b652c37127c115e885ef462b5.setContent(html_ad68b0f5f72b20551cf1ce893ffd4781);
#
#
#         marker_e8f8247b2a3f4a3c1464e45837924130.bindPopup(popup_1917037b652c37127c115e885ef462b5)
#         ;
#
#
#
#
#             var marker_b78806dc7fa141955b967b4c16b59842 = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}
#             ).addTo(map_e073045958b63e25b99eb988a35d2b4e);

# %%
seoul_map = folium.Map(location=[37.4921263, 126.9261711], zoom_start=12, tiles='Stamen Terrain')

for name, lat, lng in zip(df.index, df.위도, df.경도):
  folium.CircleMarker([lat, lng], 
                      radius=10,
                      color='brown',
                      fill=True,
                      fill_color='coral',
                      fill_opacity=0.7,
                      popup=name).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d463ba4934a942da10a198a28bd38deb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d463ba4934a942da10a198a28bd38deb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d463ba4934a942da10a198a28bd38deb = L.map(
#                 &quot;map_d463ba4934a942da10a198a28bd38deb&quot;,
#                 {
#                     center: [37.4921263, 126.9261711],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a94c7bd02e36e917b1820f9f554b8ab = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d463ba4934a942da10a198a28bd38deb);
#
#
#             var circle_marker_4828b5fb5f7426e2a8ffb3c2d403b2b5 = L.circleMarker(
#                 [37.592573, 127.046737],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d463ba4934a942da10a198a28bd38deb);
#
#
#         var popup_88c87dc039546ebe5aaecdd6969c6c56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6f182e280d7c65574c945301d2e20b49 = $(`&lt;div id=&quot;html_6f182e280d7c65574c945301d2e20b49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#             popup_88c87dc039546ebe5aaecdd6969c6c56.setContent(html_6f182e280d7c65574c945301d2e20b49);
#
#
#         circle_marker_4828b5fb5f7426e2a8ffb3c2d403b2b5.bindPopup(popup_88c87dc039546ebe5aaecdd6969c6c56)
#         ;
#
#
#
#
#             var circle_marker_26f2f24d470bc4ec39615920af8f7891 = L.circleMarker(
#                 [37.5483449, 126.8547974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d463ba4934a942da10a198a28bd38deb);
#
#
#         var popup_9be0b17364958c48f90e4f15811d378d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3837a47c8bbcfe737915a258cc72f65a = $(`&lt;div id=&quot;html_3837a47c8bbcfe737915a258cc72f65a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#             popup_9be0b17364958c48f90e4f15811d378d.setContent(html_3837a47c8bbcfe737915a258cc72f65a);
#
#
#         circle_marker_26f2f24d470bc4ec39615920af8f7891.bindPopup(popup_9be0b17364958c48f90e4f15811d378d)
#         ;
#
#
#
#
#             var circle_marker_ce719753196c3a5973954bf24712dc21 = L.circleMarker(
#                 [37.5859218, 127.0043275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d463ba4934a942da10a198a28bd38deb);
#
#
#         var popup_513c72e1feef774213cefeef2b5d73d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bc97e14d1dbfd9db9c8fd4634a3e12ef = $(`&lt;div id=&quot;html_bc97e14d1dbfd9db9c8fd4634a3e12ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#             popup_513c72e1feef774213cefeef2b5d73d4.setContent(html_bc97e14d1dbfd9db9c8fd4634a3e12ef);
#
#
#         circle_marker_ce719753196c3a5973954bf24712dc21.bindPopup(popup_513c72e1feef774213cefeef2b5d73d4)
#         ;
#
#
#
#
#             var circle_marker_f0efeba83b995f51f3c4e4accabf1023 = L.circleMarker(
#                 [37.4996227, 127.0060653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&q

# %% [markdown]
# ## 예제2 : 경기도 지역 인구수 변화

# %%
import json

file_path = './경기도인구데이터.xlsx'

df = pd.read_excel(file_path, index_col='구분', engine='openpyxl')

df.columns = df.columns.map(str) # 년도만 따로 뽑아냄.

df.head()
# Out:
#           2007    2008    2009    2010    2011    2012    2013    2014  \
# 구분
# 수원시장안구  287474  285803  290798  293692  290999  291757  300908  301196
# 수원시권선구  310553  308177  304097  306783  321176  332633  331773  339835
# 수원시팔달구  216945  213235  219833  216503  209772  206794  204805  203479
# 수원시영통구  252730  260210  258421  260557  266542  289074  310671  329718
# 성남시수정구  256744  248452  242161  241070  236123  233997  228167  223539
#
#           2015    2016    2017
# 구분
# 수원시장안구  299016  296479  293828
# 수원시권선구  351053  358393  365653
# 수원시팔달구  199180  198515  193311
# 수원시영통구  335375  340654  349836
# 성남시수정구  219531  232841  236932

# %%
geo_path = './경기도행정구역경계.json'

try:
  geo_data = json.load(open(geo_path, encoding='utf-8'))
except:
  geo_data = json.load(open(geo_path, encoding='utf-8-sig'))

g_map = folium.Map(location=[37.4921263, 126.9261711], tiles='Stamen Terrain', zoom_staste=9)

year = '2017'

folium.Choropleth(geo_data=geo_data,
                  data=df[year],
                  columns=[df.index, df[year]],
                  fill_color='YlOrRd',
                  fill_opacity=0.7,
                  line_opacity=0.3,
                  threshold_scale=[10000, 100000, 300000, 500000, 700000],
                  key_on='feature.properties.name').add_to(g_map)

g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f428f06c8c0d1e9a8adada56dbe2766e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f428f06c8c0d1e9a8adada56dbe2766e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f428f06c8c0d1e9a8adada56dbe2766e = L.map(
#                 &quot;map_f428f06c8c0d1e9a8adada56dbe2766e&quot;,
#                 {
#                     center: [37.4921263, 126.9261711],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     zoomStaste: 9,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_829f15f03909fd7ca68186b0aa79080d = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f428f06c8c0d1e9a8adada56dbe2766e);
#
#
#             var choropleth_fd859859b07c3323697cb9d76cdf6584 = L.featureGroup(
#                 {}
#             ).addTo(map_f428f06c8c0d1e9a8adada56dbe2766e);
#
#
#         function geo_json_3a7c7611ee61459d2f75b1c738adbd1c_styler(feature) {
#             switch(feature.properties.code) {
#                 case 31370: case 31350: case 31110: case 31080:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31250: case 31230: case 31200: case 31193: case 31192: case 31150: case 31101: case 31092: case 31091: case 31070: case 31060: case 31051: case 31042: case 31030: case 31014: case 31012:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31240: case 31130: case 31023:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e31a1c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_3a7c7611ee61459d2f75b1c738adbd1c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3a7c7611ee61459d2f75b1c738adbd1c = L.geoJson(null, {
#                 onEachFeature: geo_json_3a7c7611ee61459d2f75b1c738adbd1c_onEachFeature,
#
#                 style: geo_json_3a7c7611ee61459d2f75b1c738adbd1c_styler,
#         });
#
#         function geo_json_3a7c7611ee61459d2f75b1c738adbd1c_add (data) {
#             geo_json_3a7c7611ee61459d2f75b1c738adbd1c
#                 .addData(data)
#                 .addTo(choropleth_fd859859b07c3323697cb9d76cdf6584);
#         }
#             geo_json_3a7c7611ee61459d2f75b1c738adbd1c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.56113535909492, 37.6256560539258], [127.57290963929243, 37.61087369350498], [127.56366973908277, 37.5842624297699], [127.52226606559191, 37.5828628697518], [127.50048767007603, 37.569036373178626], [127.47687473909174, 37.574448241913856], [127.47565866803647, 37.60512112601634], [127.44699730711024, 37.64497584741164], [127.4272349102434, 37.66284420898682], [127.40156700708162, 37.64806970784708], [127.3732642199939, 37.6453987554284], [127.3542931884407, 37.6250006376975], [127.34360057873045, 37.588997440929354], [127.31002843450217, 37.53523876142835], [127.30923294884336, 37.5135706079458], [127.32809611134748, 37.53133849534739], [127.3663244453597, 37.52716845880826], [127.38286320755414, 37.50147517965334], [127.39046783039153, 37.47413422098595], [127.37490698722792, 37.455072688441305], [127.39174400683049, 37.4256483411369], [127.40276739880215, 37.41856433413549], [127.4250053080982, 37.43669952587185], [127.4817900304572, 37.42084413829662], [127.51015267026155, 37.43699555518635], [127.52501209957308, 37.43192043868044], [127.53910572062166, 37.40849283821634], [127.60528700481163, 37.416969769508924], [127.63754040237271, 37.41065607591271], [127.6491838950862, 37.402042953108506], [127.66976823475012, 37.40884431255766], [127.71071536074867, 37.40736583858037], [127.70347417929173, 37.371054026073324], [127.76165381178268, 37.36421926003675], [127.77952402154285, 37.368441789396854], [127.80397287036232, 37.432516049235865], [127.79833492163134, 37.460500237870505], [127.77664798308412, 37.48883635932707], [127.77611527652192, 37.50328615763377], [127.80855972024105, 37.53220450961153],

# %% [markdown]
# ## 예제3 : 공공데이터를 활용해 지도 시각화하기

# %% [markdown]
# ### 주제 : 경기도 수원시 녹지현황
#
# - 녹지의 구분 : 완충녹지, 경관녹지, 연결녹지
#
# - 완충녹지는 연한 녹색, 경관녹지는 좀 더 진한 녹색, 연결녹지는 파란색으로 나타내었는데 지도에 찍힌 결과를 보니 연결녹지의 수가 현저히 적은 것을 확인할 수 있었다.
#
# - 또한, 원의 크기는 해당 녹지의 면적에 비례하는데 광교(사진 상 가장 큰 원이 존재하는 곳) 부근에서 녹지 면적이 가장 크게 나타나는 것을 확인할 수 있었다.

# %%
# 데이터 불러오기
df = pd.read_csv('./경기도 수원시_녹지현황_20220808.csv', encoding='cp949', index_col=0)
df.head()
# Out:
#            녹지구분                 녹지위치         위도          경도      면적  \
# 녹지등록명
# 연결녹지 제3호   연결녹지     영통구 매탄동 1209-3번지  37.268801  127.053252  1998.7
# 연결녹지 제8호   연결녹지    권선구 권선동 1354-57번지  37.236757  127.023343  3475.0
# 연결녹지 제9호   연결녹지  장안구 조원동 519-74번지 일원  37.297789  127.019117  2873.0
# 연결녹지 제10호  연결녹지        팔달구 화서동 770번지  37.288027  127.002207   870.0
# 연결녹지 제11호  연결녹지        팔달구 화서동 771번지  37.287712  127.002732   190.0
#
#                  결정일자     데이터기준일자
# 녹지등록명
# 연결녹지 제3호   1991-02-08  2022-08-08
# 연결녹지 제8호   2008-11-04  2022-08-08
# 연결녹지 제9호   2009-01-20  2022-08-08
# 연결녹지 제10호  2009-03-13  2022-08-08
# 연결녹지 제11호  2009-03-13  2022-08-08

# %%
# 수원 지도
suwon_map = folium.Map(location=[37.2635727, 127.0286009], zoom_start=12, tiles='Stamen Terrain')

# %%
color_map = {'완충녹지':'honeydew', '경관녹지':'palegreen', '연결녹지':'deepskyblue'}

for name, cate, lat, lng, size in zip(df.index, df.녹지구분, df.위도, df.경도, df.면적):
  folium.CircleMarker([lat, lng], 
                      radius=size/1000,
                      color='black',
                      fill=True,
                      fill_color=color_map[cate],
                      fill_opacity=0.7,
                      popup=name).add_to(suwon_map)

suwon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_316c15b5284a456d5bb14dadb25f4039 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_316c15b5284a456d5bb14dadb25f4039&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_316c15b5284a456d5bb14dadb25f4039 = L.map(
#                 &quot;map_316c15b5284a456d5bb14dadb25f4039&quot;,
#                 {
#                     center: [37.2635727, 127.0286009],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4d3922f0f3ecf61261258e964d886f6 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_316c15b5284a456d5bb14dadb25f4039);
#
#
#             var circle_marker_5554b3152ca4cebed626b31de119c208 = L.circleMarker(
#                 [37.26880084, 127.0532515],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;deepskyblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.9987000000000001, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_316c15b5284a456d5bb14dadb25f4039);
#
#
#         var popup_262b5a9eb082e4840566353b8c0a11b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d693d33daab83baabd5b88c5d465698a = $(`&lt;div id=&quot;html_d693d33daab83baabd5b88c5d465698a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연결녹지 제3호&lt;/div&gt;`)[0];
#             popup_262b5a9eb082e4840566353b8c0a11b4.setContent(html_d693d33daab83baabd5b88c5d465698a);
#
#
#         circle_marker_5554b3152ca4cebed626b31de119c208.bindPopup(popup_262b5a9eb082e4840566353b8c0a11b4)
#         ;
#
#
#
#
#             var circle_marker_6243a0b9fadfa3c7c8a9162dd84bea06 = L.circleMarker(
#                 [37.23675667, 127.0233427],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;deepskyblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.475, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_316c15b5284a456d5bb14dadb25f4039);
#
#
#         var popup_77d0fae3ca07586f667ecef705216391 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_09b56e96e918da6539adb9287fd8b8b2 = $(`&lt;div id=&quot;html_09b56e96e918da6539adb9287fd8b8b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연결녹지 제8호&lt;/div&gt;`)[0];
#             popup_77d0fae3ca07586f667ecef705216391.setContent(html_09b56e96e918da6539adb9287fd8b8b2);
#
#
#         circle_marker_6243a0b9fadfa3c7c8a9162dd84bea06.bindPopup(popup_77d0fae3ca07586f667ecef705216391)
#         ;
#
#
#
#
#             var circle_marker_d572a111f9d507cfd16b4358ef3acda3 = L.circleMarker(
#                 [37.29778895, 127.0191172],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;deepskyblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.873, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_316c15b5284a456d5bb14dadb25f4039);
#
#
#         var popup_5a644c2a124000ff67426cf52ce9a8a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ac7a9469619c85a93b5adad877bb7a37 = $(`&lt;div id=&quot;html_ac7a9469619c85a93b5adad877bb7a37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연결녹지 제9호&lt;/div&gt;`)[0];
#             popup_5a644c2a124000ff67426cf52ce9a8a5.setContent(html_ac7a9469619c85a93b5adad877bb7a37);
#
#
#         circle_marker_d572a111f9d507cfd16b4358ef3acda3.bindPopup(popup_5a644c2a124000ff67426cf52ce9a8a5)
#         ;
#
#
#
#
#             var circle_marker_5ad678784b206e73a0832c5dbe95ebc8 = L.circleMarker(
#                 [37.28802747, 127.0022068],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &
